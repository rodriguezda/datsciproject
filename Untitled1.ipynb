# %%
import pandas as pd

# %%
ahip = pd.read_csv('ahip.csv')

# %%
ahip.head()
# Out:
#        id   request_time login_type         server request_method  \
# 0  285913    7/7/16 9:10       ahip  ahip.pmdev.us           POST
# 1  285902  6/30/16 16:22       ahip  ahip.pmdev.us           POST
# 2  285880  6/22/16 18:03       ahip  ahip.pmdev.us           POST
# 3  285879  6/22/16 18:03       ahip  ahip.pmdev.us           POST
# 4  285878  6/22/16 17:25       ahip  ahip.pmdev.us           POST
#
#            request_uri request_query_string        user_ip  \
# 0              /login/                  NaN  66.208.58.100
# 1  /login?uri=/profile         uri=/profile  38.105.65.250
# 2              /login/                  NaN  66.208.58.100
# 3              /login/                  NaN  66.208.58.100
# 4              /login/                  NaN  66.208.58.100
#
#                                           user_agent  \
# 0  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5...
# ...

# %%
ahip.describe()
# Out:
#                   id  password
# count       5.000000         0
# mean   285890.400000       NaN
# std        16.102795       NaN
# min    285878.000000       NaN
# 25%    285879.000000       NaN
# 50%    285880.000000       NaN
# 75%    285902.000000       NaN
# max    285913.000000       NaN
